# %%
image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (640,640))
plt.imshow(image,cmap="gray")

# %%
#Sobel-45* Operator
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (640,640))
kernel = np.array([[0,-1,-2], [1,0,-1], [2,1,0]])
image = cv2.filter2D(image, -1, kernel)

plt.imshow(image,cmap="gray")
plt.show()

# %%
#Conv1
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (640,640))
kernel = np.array([[-1,-1,-1], [-1,8,-1], [-1,-1,-1]])
image = cv2.filter2D(image, -1, kernel)

plt.imshow(image,cmap="gray")
plt.show()

# %%
#Laplacian filter//sharping//edge detect
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (640,640))
kernel = np.array([[0,-1,0], [-1,4,-1], [0,-1,0]])
image = cv2.filter2D(image, -1, kernel)

plt.imshow(image,cmap="gray")
plt.show()

# %%
#Gaussian 7x7//blur//smooth
import numpy as np
import matplotlib.pyplot as plt
import cv2

image = cv2.imread('image1.png', cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (640,640))
kernel = np.array([
    [0.000036, 0.000363, 0.001446, 0.002290, 0.001446, 0.000363, 0.000036],
    [0.000363, 0.003676, 0.014652, 0.023199, 0.014652, 0.003676, 0.000363],
    [0.001446, 0.014652, 0.058608, 0.092651, 0.058608, 0.014652, 0.001446],
    [0.002290, 0.023199, 0.092651, 0.146768, 0.092651, 0.023199, 0.002290],
    [0.001446, 0.014652, 0.058608, 0.092651, 0.058608, 0.014652, 0.001446],
    [0.000363, 0.003676, 0.014652, 0.023199, 0.014652, 0.003676, 0.000363],
    [0.000036, 0.000363, 0.001446, 0.002290, 0.001446, 0.000363, 0.000036]
])
image = cv2.filter2D(image, -1, kernel)

plt.imshow(image,cmap="gray")
plt.show()
